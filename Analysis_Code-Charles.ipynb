# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# as well as an

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
# from cycler import cycler
# plt.style.use('ggplot')
# data = np.random.randn(50)

# %%
# print(plt.style.available)

# %%
# plt.style.use('seaborn-darkgrid')

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %% [markdown]
# SAT score for Maryland 52 should be 524
# ACT score 2.3 for Maryland should be 23.8 (based off math)
# ACT comp score for Wyoming should be 20.2 not 20.2x

# %%
#Code:
sat_2017 = pd.read_csv('~/Desktop/DSI/Submissions/Projects/project_1-master/data/sat_2017.csv')

# %%
act_2017 = pd.read_csv('~/Desktop/DSI/Submissions/Projects/project_1-master/data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
sat_2017.head(11)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
#
#     Math  Total
# 0    572   1165
# 1    533   1080
# ...

# %%
sat_2017
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
act_2017
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %%
act_2017.head(11)
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
#
#    Composite
# 0       21.0
# 1       19.2
# 2       19.8
# 3       19.7
# 4       19.4
# 5       22.8
# ...

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %%
#Answer: 
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# Between all states included whom conducted SAT exams in 2017 & 2018; if the recorded rate of participation tended to be higher the scores averaged lower vs. a recorded lower rate a higher score upon the exam. Colorado dispalyed significant increases in SAT participation, likely due to removing the ACT as mandatory. This introduces an intriguing position being which potentially due to institutions offering both the ACT &; SAT, the choice itself by the institution to offer a specific exam is important. Notably, a state with high participation in one test trends toward lower participation in the other. Analogous data is acquired in 2018; ACT participation rates prevail across most states with around 20 states recording 100% participation. Furthering my conjecture of removing the ACT examination from usage.

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: yes, without having any null values, if true then there will be null value.

# %%
sat_2017.isnull()
# Out:
#     State  Participation  Evidence-Based Reading and Writing   Math  Total
# 0   False          False                               False  False  False
# 1   False          False                               False  False  False
# 2   False          False                               False  False  False
# 3   False          False                               False  False  False
# 4   False          False                               False  False  False
# 5   False          False                               False  False  False
# 6   False          False                               False  False  False
# 7   False          False                               False  False  False
# 8   False          False                               False  False  False
# 9   False          False                               False  False  False
# 10  False          False                               False  False  False
# ...

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# SAT Minimum possible score is 400; 200 for each total 1600. ACT, 1 point per subject, 30 composite.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#code 
#sat.loc[column index , row index] = new value

# %%
sat_2017[sat_2017['State'] == 'Maryland']
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %%
#code
sat_2017.iloc[20, 3] = 524

# %%
sat_2017
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
#identify error in Maryland science score and adjust to proper score average.
act_2017.iloc[21, 5] = 23.8

# %%
act_2017
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: ACT Parcipitation & composite should be replaced as floats for precision instead of objects. SAT participation should be float.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#Dataframe into dataframe, within a type conversion from a string(object) into a float.
#converting participation into a string without a "%".
sat_2017['Participation']= sat_2017.Participation.str.replace('%', '').astype(float)

# %%
sat_2017.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
#Dataframe into dataframe, within a type conversion from a string(object) into a float.
act_2017['Participation']= act_2017.Participation.str.replace('%', '').astype(float)


#Dataframe into dataframe, within a type conversion from a string(object) into a float.
act_2017['Composite'] = act_2017.Composite.str.replace('x', '').astype(float)

# %%
act_2017
# Out:
#                    State  Participation  English  Math  Reading  Science  \
# 0               National           60.0     20.3  20.7     21.4     21.0
# 1                Alabama          100.0     18.9  18.4     19.7     19.4
# 2                 Alaska           65.0     18.7  19.8     20.4     19.9
# 3                Arizona           62.0     18.6  19.8     20.1     19.8
# 4               Arkansas          100.0     18.9  19.0     19.7     19.5
# 5             California           31.0     22.5  22.7     23.1     22.2
# 6               Colorado          100.0     20.1  20.3     21.2     20.9
# 7            Connecticut           31.0     25.5  24.6     25.6     24.6
# 8               Delaware           18.0     24.1  23.4     24.8     23.6
# 9   District of Columbia           32.0     24.4  23.5     24.9     23.5
# 10               Florida           73.0     19.0  19.4     21.0     19.4
# 11               Georgia           55.0     21.0  20.9     22.0     21.3
# ...

# %%
#act['State'] = act.State.replace(' ', '').astype(str)

# %%
#code
sat_2017['Math'] = sat_2017['Math'].astype(float)

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
# sat_2017['Participation']= sat_2017.Participation.str.replace('%', '').astype(float)
# act_2017['Participation']= act_2017.Participation.str.replace('%', '').astype(float)
# act_2017['Composite'] = act_2017.Composite.str.replace('x', '').astype(float)
# act_2017.iloc[21, 5] = 23.8
# sat_2017.iloc[20, 3] = 524

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code
act_2017.loc[act_2017['State'] == 'Maryland']
# Out:
#        State  Participation  English  Math  Reading  Science  Composite
# 21  Maryland           28.0     23.3  23.1     24.2     23.8       23.6

# %%
sat_2017
# Out:
#                    State  Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5.0                                 593
# 1                 Alaska           38.0                                 547
# 2                Arizona           30.0                                 563
# 3               Arkansas            3.0                                 614
# 4             California           53.0                                 531
# 5               Colorado           11.0                                 606
# 6            Connecticut          100.0                                 530
# 7               Delaware          100.0                                 503
# 8   District of Columbia          100.0                                 482
# 9                Florida           83.0                                 520
# 10               Georgia           61.0                                 535
# ...

# %%
act_2017
# Out:
#                    State  Participation  English  Math  Reading  Science  \
# 0               National           60.0     20.3  20.7     21.4     21.0
# 1                Alabama          100.0     18.9  18.4     19.7     19.4
# 2                 Alaska           65.0     18.7  19.8     20.4     19.9
# 3                Arizona           62.0     18.6  19.8     20.1     19.8
# 4               Arkansas          100.0     18.9  19.0     19.7     19.5
# 5             California           31.0     22.5  22.7     23.1     22.2
# 6               Colorado          100.0     20.1  20.3     21.2     20.9
# 7            Connecticut           31.0     25.5  24.6     25.6     24.6
# 8               Delaware           18.0     24.1  23.4     24.8     23.6
# 9   District of Columbia           32.0     24.4  23.5     24.9     23.5
# 10               Florida           73.0     19.0  19.4     21.0     19.4
# 11               Georgia           55.0     21.0  20.9     22.0     21.3
# ...

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#display the appropriate data types sat 
sat_2017.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                  float64
# Total                                   int64
# dtype: object

# %%
#display the appropriate data types act
act_2017.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#identify columns to be changed
sat_2017.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing   Math  Total
# 0     Alabama            5.0                                 593  572.0   1165
# 1      Alaska           38.0                                 547  533.0   1080
# 2     Arizona           30.0                                 563  553.0   1116
# 3    Arkansas            3.0                                 614  594.0   1208
# 4  California           53.0                                 531  524.0   1055

# %%
# rectify column nomenclature act
act_2017.rename(columns={
    'State':'state',
    'Participation' : 'participation.act.2017',
    'English' : 'english.act.2017',
    'Math' : 'math.act.2017',
    'Reading' : 'reading.act.2017',
    'Science' : 'science.act.2017',
    'Composite' : 'composite.act.2017',
}, inplace=True)

# %%
# rectify column nomenclature sat
sat_2017.rename(columns={
    'State':'state',
    'Participation' : 'participation.sat.2017',
    'Evidence-Based Reading and Writing' : 'eb.r&w.sat.2017',
    'Math' : 'math.sat.2017',
    'Total' : 'total.sat.2017'
}, inplace=True)

# %%
# sat_2017['shape'].str.lower()

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT or SAT|State Name|
# sat_participation_2017|Float|SAT|SAT Student Participation(2017)|
# sat_writing_17|Int|SAT|Average SAT Writing Score (200-800)|
# sat_math_17|Int|SAT|Average SAT Math Score (200-800)|
# sat_total_17|Int|SAT|Average SAT Total Score (200-800)|
# act_participation_2017|Float|ACT|ACT Student Participation (2017)|
# act_english_2017|Float|ACT|Average ACT English Score (1-36)|
# act_math_2017|Float|ACT|Average ACT Math Score (1-36)|
# act_reading_2017|Float|ACT|Average ACT Reading Score (1-36)|
# act_science_2017|Float|ACT|Average ACT Science Score (1-36)|
# act_composite_17|Float|ACT|Average ACT Composite Score (1-36)|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#code
act_2017 = act_2017[1:]

# %%
act_2017
# Out:
#                    state  participation.act.2017  english.act.2017  \
# 1                Alabama                   100.0              18.9
# 2                 Alaska                    65.0              18.7
# 3                Arizona                    62.0              18.6
# 4               Arkansas                   100.0              18.9
# 5             California                    31.0              22.5
# 6               Colorado                   100.0              20.1
# 7            Connecticut                    31.0              25.5
# 8               Delaware                    18.0              24.1
# 9   District of Columbia                    32.0              24.4
# 10               Florida                    73.0              19.0
# 11               Georgia                    55.0              21.0
# 12                Hawaii                    90.0              17.8
# 13                 Idaho                    38.0              21.9
# ...

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#test_scores_17 
#movie_reviews = pd.merge(ratings, movies, how='left')
test_scores_2017 = pd.merge(sat_2017, act_2017, how='outer',on=['state'])

# %%
test_scores_2017.head()
# Out:
#         state  participation.sat.2017  eb.r&w.sat.2017  math.sat.2017  \
# 0     Alabama                     5.0              593          572.0
# 1      Alaska                    38.0              547          533.0
# 2     Arizona                    30.0              563          553.0
# 3    Arkansas                     3.0              614          594.0
# 4  California                    53.0              531          524.0
#
#    total.sat.2017  participation.act.2017  english.act.2017  math.act.2017  \
# 0            1165                   100.0              18.9           18.4
# 1            1080                    65.0              18.7           19.8
# 2            1116                    62.0              18.6           19.8
# 3            1208                   100.0              18.9           19.0
# 4            1055                    31.0              22.5           22.7
#
#    reading.act.2017  science.act.2017  composite.act.2017
# ...

# %%
sat_2017 = sat_2017.drop_duplicates(keep='last')

# %%
act_2017 = act_2017.drop_duplicates(keep='last')

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
# test_score_2017.to_csv('~/Desktop/DSI/Submissions/Projects/project_1-master/data/combined_2017.csv')
test_scores_2017.to_csv('..\\data\\combined_2017.csv', index=False)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Read in the `sat_2018.csv` and `act_2018.csv` files and assign them to appropriately named pandas dataframes. For the **2018 ACT Data**, only the `Composite` scores are available. Repeat the same processes to clean the 2018 data here as you were instructed in the previous sections above.

# %%
sat_2018 = pd.read_csv('~/Desktop/DSI/Submissions/Projects/project_1-master/data/sat_2018.csv')
act_2018 = pd.read_csv('~/Desktop/DSI/Submissions/Projects/project_1-master/data/act_2018.csv')

# %%
act_2018.rename(columns={
    'State':'state',
    'Participation' : 'participation.act.2018',
    'English' : 'english.act.2018',
    'Math' : 'math.act.2018',
    'Reading' : 'reading.act.2018',
    'Science' : 'science.act.2018',
    'Composite' : 'composite.act.2018',
}, inplace=True)

# %%
# act_2018.iloc[8,0]

# %%
# sat_2017.at[20,'Math']=524
# act_2018.at[8, ‘state’] = ‘District of Columbia’

# %%
act_2018.loc[act_2018['state'] == 'District of columbia','state']= 'District of Columbia'

# %%
act_2018.loc[act_2018['state'] == 'District of Columbia','state']
# Out:
# 8    District of Columbia
# Name: state, dtype: object

# %%
# act_2018.iloc[:9,:1].replace(to_replace="c",value="C",inplace=True)

# %%
act_2018
# Out:
#                    state participation.act.2018  composite.act.2018
# 0                Alabama                   100%                19.1
# 1                 Alaska                    33%                20.8
# 2                Arizona                    66%                19.2
# 3               Arkansas                   100%                19.4
# 4             California                    27%                22.7
# 5               Colorado                    30%                23.9
# 6            Connecticut                    26%                25.6
# 7               Delaware                    17%                23.8
# 8   District of Columbia                    32%                23.6
# 9                Florida                    66%                19.9
# 10               Georgia                    53%                21.4
# 11                Hawaii                    89%                18.9
# 12                 Idaho                    36%                22.3
# ...

# %%
sat_2018.rename(columns={
    'State':'state',
    'Participation' : 'participation.sat.2018',
    'Evidence-Based Reading and Writing' : 'eb.r&w.sat.2018',
    'Math' : 'math.sat.2018',
    'Total' : 'total.sat.2018'
}, inplace=True)

# %%
sat_2018
# Out:
#                    state participation.sat.2018  eb.r&w.sat.2018  \
# 0                Alabama                     6%              595
# 1                 Alaska                    43%              562
# 2                Arizona                    29%              577
# 3               Arkansas                     5%              592
# 4             California                    60%              540
# 5               Colorado                   100%              519
# 6            Connecticut                   100%              535
# 7               Delaware                   100%              505
# 8   District of Columbia                    92%              497
# 9                Florida                    56%              550
# 10               Georgia                    70%              542
# 11                Hawaii                    56%              480
# 12                 Idaho                   100%              508
# ...

# %%
test_scores_2018 = pd.merge(sat_2018, act_2018, how='left')

# %%
test_scores_2018.to_csv('..\\data\\combined_2018.csv',index=False)

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
# final = pd.merge(test_scores_2017, test_scores_2018, how='left', left_index=False, right_index=False)
final = pd.merge(test_scores_2017, test_scores_2018, how='left')
# (test_scores_2018_scores, on='State',how='inner', suffixes=('', ''))

# %%
final.drop_duplicates(keep='last')
# Out:
#                    state  participation.sat.2017  eb.r&w.sat.2017  \
# 0                Alabama                     5.0              593
# 1                 Alaska                    38.0              547
# 2                Arizona                    30.0              563
# 3               Arkansas                     3.0              614
# 4             California                    53.0              531
# 5               Colorado                    11.0              606
# 6            Connecticut                   100.0              530
# 7               Delaware                   100.0              503
# 8   District of Columbia                   100.0              482
# 9                Florida                    83.0              520
# 10               Georgia                    61.0              535
# 11                Hawaii                    55.0              544
# 12                 Idaho                    93.0              513
# ...

# %%
final_T = final.transpose()
final_T
# Out:
#                              0       1        2         3           4   \
# state                   Alabama  Alaska  Arizona  Arkansas  California
# participation.sat.2017        5      38       30         3          53
# eb.r&w.sat.2017             593     547      563       614         531
# math.sat.2017               572     533      553       594         524
# total.sat.2017             1165    1080     1116      1208        1055
# participation.act.2017      100      65       62       100          31
# english.act.2017           18.9    18.7     18.6      18.9        22.5
# math.act.2017              18.4    19.8     19.8        19        22.7
# reading.act.2017           19.7    20.4     20.1      19.7        23.1
# science.act.2017           19.4    19.9     19.8      19.5        22.2
# composite.act.2017         19.2    19.8     19.7      19.4        22.8
# participation.sat.2018       6%     43%      29%        5%         60%
# ...

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT or SAT|State Name|
# sat_participation_2018|Float|SAT|SAT Student Participation(2018)|
# sat_writing_18|Int|SAT|Average SAT Writing Score (200-800)|
# sat_math_18|Int|SAT|Average SAT Math Score (200-800)|
# sat_total_18|Int|SAT|Average SAT Total Score (200-800)|
# act_participation_2018|Float|ACT|ACT Student Participation (2018)|
# act_english_2018|Float|ACT|Average ACT English Score (1-36)|
# act_math_2018|Float|ACT|Average ACT Math Score (1-36)|
# act_reading_2018|Float|ACT|Average ACT Reading Score (1-36)|
# act_science_2018|Float|ACT|Average ACT Science Score (1-36)|
# act_composite_18|Float|ACT|Average ACT Composite Score (1-36)|

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
import statistics

# %%
final.describe()
# Out:
#        participation.sat.2017  eb.r&w.sat.2017  math.sat.2017  total.sat.2017  \
# count               52.000000        52.000000      52.000000       52.000000
# mean                40.865385       568.038462     555.769231     1123.903846
# std                 35.757916        45.881758      47.342563       92.940263
# min                  2.000000       482.000000     468.000000      950.000000
# 25%                  4.000000       531.750000     522.500000     1054.250000
# 50%                 40.500000       558.500000     544.500000     1104.500000
# 75%                 67.500000       612.500000     597.000000     1210.000000
# max                100.000000       644.000000     651.000000     1295.000000
#
#        participation.act.2017  english.act.2017  math.act.2017  \
# count               52.000000         52.000000      52.000000
# mean                64.153846         20.994231      21.236538
# std                 32.799680          2.374159       2.000983
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
final['composite.act.2017'].std()
# Out:
# 2.0375990662422114

# %%
# #code
import math
        #mean is calculated by the sum of total values divided by the number of values.
def stanDev(data):
    composite= []
    length = len(data)
    mean = float(sum(data))/ len((data))
    sum_total  = 0
    for e in data:
        sum_total += (e - mean) ** 2
        
    under_root = float(sum_total) / (length - 1)
    
    return (under_root)
stanDev(final['composite.act.2017'])
# Out:
# 4.1518099547511325

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
# #unfortuately unable to rectify 
# {key: value for key, value in d.items()}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
sat_2017.head()
# Out:
#         state  participation.sat.2017  eb.r&w.sat.2017  math.sat.2017  \
# 0     Alabama                     5.0              593          572.0
# 1      Alaska                    38.0              547          533.0
# 2     Arizona                    30.0              563          553.0
# 3    Arkansas                     3.0              614          594.0
# 4  California                    53.0              531          524.0
#
#    total.sat.2017
# 0            1165
# 1            1080
# 2            1116
# 3            1208
# 4            1055

# %%
# #code
# sat_2017.sort_values('participation_sat_2017', ascending=True).head().T
# sat_2018.sort_values('participation_sat_2018', ascending=True).head().T

# %%
sat_2017
# Out:
#                    state  participation.sat.2017  eb.r&w.sat.2017  \
# 0                Alabama                     5.0              593
# 1                 Alaska                    38.0              547
# 2                Arizona                    30.0              563
# 3               Arkansas                     3.0              614
# 4             California                    53.0              531
# 5               Colorado                    11.0              606
# 6            Connecticut                   100.0              530
# 7               Delaware                   100.0              503
# 8   District of Columbia                   100.0              482
# 9                Florida                    83.0              520
# 10               Georgia                    61.0              535
# 11                Hawaii                    55.0              544
# 12                 Idaho                    93.0              513
# ...

# %%
sat_2018
# Out:
#                    state participation.sat.2018  eb.r&w.sat.2018  \
# 0                Alabama                     6%              595
# 1                 Alaska                    43%              562
# 2                Arizona                    29%              577
# 3               Arkansas                     5%              592
# 4             California                    60%              540
# 5               Colorado                   100%              519
# 6            Connecticut                   100%              535
# 7               Delaware                   100%              505
# 8   District of Columbia                    92%              497
# 9                Florida                    56%              550
# 10               Georgia                    70%              542
# 11                Hawaii                    56%              480
# 12                 Idaho                   100%              508
# ...

# %%
# act_2017.sort_values('participation_act_2017', ascending=True).head().T
# act_2018.sort_values('participation_act_2018', ascending=True).head().T

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
# plt.figure(figsize=(12,12))
# # sns.heatmap(heart_df.corr(), annot=True, cmap='plasma', vmax= 1.0, vmin=-1.0);
plt.figure(figsize=(12, 10))
# Mask to remove upper triangle
mask = np.triu(np.ones_like(final.corr(), dtype=np.bool))
ax = plt.axes()
sns.heatmap(final.corr(), 
            annot=True, 
            cmap="Blues", 
            vmax=1.0, 
            vmin=-1.0, 
            mask=mask,
            ax=ax);
ax.set_title('Patricipation vs Score', fontsize=30);

# %%
#correlation heat mat, framework cited from stackoverflow :user eamonfleming
fig = plt.figure(figsize=(12,12))
ax = sns.heatmap(final.corr(),annot=True,cmap="PuBu", center=0)
ax.set_title('Correlation Heatmap Between SAT and ACT\n');

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, figsize_tuple, bins_range = None):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(figsize=figsize_tuple,nrows=nrows, ncols=2) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
            ax[i].hist(dataframe[column],bins=bins_range) # feel free to add more settings
            ax[i].set_title(list_of_titles[i])# Set titles, labels, etc here for each subplot
            ax[i].set_xlabel(list_of_xlabels[i])

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
subplot_histograms(final,
['math.sat.2017','math.act.2017'],
['Mean SAT Math Score 2017','Mean ACT Math Score 2017'],
['Mean Score','Mean Score'],
(12,5)
)

# %%
# subplot_histograms(
# 	final,
# 	['participation.sat.2017','participation.act.2017'],
# 	['SAT Participation 2017','ACT Participation 2017',],
# 	['Participation Rate','Participation Rate'],
# 	(12,5),
# 	[0.1*q for q in range(0,11)]

# %%
subplot_histograms(
	final,
	['participation.sat.2018','participation.act.2018'],
	['SAT Participation 2018','ACT Participation 2018',],
	['Participation Rate','Participation Rate'],
	(12,5),
	[0.1*q for q in range(0,11)]  
)
plt.show()

# %%
# boxplots for participation rates; framework reformated from stackoverflow
rates_of_participation=final.loc[:,['participation.sat.2017','participation.sat.2018','participation.act.2018','participation.act.2017']]
rates_of_participation=rates_of_participation.rename(columns={
	'participation.sat.2017':'SAT 2017',
	'participation.sat.2018':'SAT 2018',
	'participation.act.2017':'ACT 2017',
	'participation.act.2018':'ACT 2018'
})
plt.figure(figsize=(10,6))
plt.title('Distributive Analysis Between ACT & SAT Rates of Participation, 2017-18')
sns.boxplot(data=rates_of_participation,orient='h',palette='Set2');

# %%
# Code
final.describe()
# Out:
#        participation.sat.2017  eb.r&w.sat.2017  math.sat.2017  total.sat.2017  \
# count               52.000000        52.000000      52.000000       52.000000
# mean                40.865385       568.038462     555.769231     1123.903846
# std                 35.757916        45.881758      47.342563       92.940263
# min                  2.000000       482.000000     468.000000      950.000000
# 25%                  4.000000       531.750000     522.500000     1054.250000
# 50%                 40.500000       558.500000     544.500000     1104.500000
# 75%                 67.500000       612.500000     597.000000     1210.000000
# max                100.000000       644.000000     651.000000     1295.000000
#
#        participation.act.2017  english.act.2017  math.act.2017  \
# count               52.000000         52.000000      52.000000
# mean                64.153846         20.994231      21.236538
# std                 32.799680          2.374159       2.000983
# ...

# %%
# Combined_Rates = ['participation.sat.2017' + 'participation.act.2017']
# plt.hist(final[final['Rates_combined']] == ['participation.sat.2017','participation.act.2017']['close'], bins=5)
# plt.title('Comparative Participation Rates between ACT & SAT (5 bins)');

# %%
Scores_combined = ['math.sat.2017' + 'math.act.2017']
plt.hist(final[final['Scores_combined'] == 'math.sat.2017','math.act.2017']['close'], bins=5)
plt.title('Comparative Math Scores between ACT & SAT (5 bins)');

# %%
Scores_combined = ['eb.r&w.sat.2017	', + 'english.act.2017', +'reading.act.2017']
plt.hist(final[final['Scores_combined'] == 'eb.r&w.sat.2017', 'english.act.2017','reading.act.2017']['close'], bins=5)
plt.title('Comparative Math Scores between ACT & SAT (5 bins)');

# %%
final.head()

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
def subplot_scatterplot(column1,column2,xlabel,ylabel,title):
    f = plt.figure(figsize=(8,5))
    sns.set_style('blackgrid')
    sns.scatterplot(x=final[column1],y=final[column2])
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title);

# %%
final.head()

# %%
# # Code 
plt.scatter(final['math_act_2017'], final['math_sat_2017'], alpha = 0.8, s = 12);
plt.xlabel('SAT Math Scores 2017', fontsize = 14);
plt.ylabel('ACT Math Scores 2017', fontsize = 14);

# %%
plt.scatter(final['math_act_2017'], final['math_sat_2017'], alpha = 0.8, s = 12);
plt.xlabel('SAT Math Scores 2017', fontsize = 14);
plt.ylabel('ACT Math Scores 2017', fontsize = 14);

# %%
plt.scatter(final['math_act_2017'], final['math_sat_2017'], alpha = 0.8, s = 12);
plt.xlabel('SAT Math Scores 2017', fontsize = 14);
plt.ylabel('ACT Math Scores 2017', fontsize = 14);

# %%
plt.scatter(final['math_act_2017'], final['math_sat_2017'], alpha = 0.8, s = 12);
plt.xlabel('SAT Math Scores 2017', fontsize = 14);
plt.ylabel('ACT Math Scores 2017', fontsize = 14);

# %%
plt.scatter(final['math_act_2017'], final['math_sat_2017'], alpha = 0.8, s = 12);
plt.xlabel('SAT Math Scores 2017', fontsize = 14);
plt.ylabel('ACT Math Scores 2017', fontsize = 14);

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
final.head()

# %%
# Code
# fig = final
# fig = plt.figure(figsize=(14,5))

# ax1 = fig.add_subplot(1,2,1)
# # put your plot here, use ax1 for the axes
# plt.xlabel('SAT math averages for states with participation > 90%')
# plt.ylabel("Number of States")
# plt.title("Comparison of SAT participation for 2017 and 2018")

# ax2 = fig.add_subplot(1,2,2)
# # put your plot here, use ax2 for the axes
# plt.xlabel('Year')
# plt.ylabel("Number of States")
# plt.title("SAT math averages for states with participation < 90%")

# plt.tight_layout()

plt.subplots(figsize = (8,8))
sns.boxplot(data = final[['participation.sat.2017', 'participation.sat.2018', 'participation.act.2017', 'participation.act.2018']], width = 0.5);
plt.title('SAT & ACT Participation', fontsize = 24)
plt.ylabel('Rate', fontsize = 22)
plt.ylim(0, 110)

plt.xticks(rotation = 45);

# %%
ply.scatterplot()

# %% [markdown]
# The conglomeration within the upper edge represents low-SAT-participation states, states with approx 10-15% SAT participation, Illinois is represent in this group.
#
# The Mean SAT Math score displays a peak approx 535, yet a valley approx 575, and a subliminal peak approximating in the 600s, conveying the seclusion of states with superior math scores.One would state the plausibility of this second peak conveys higher mean performance in the group of low-participation states. Yet potentially as a result of a cessation of contracts to conduct ACT exams these states recorded significant decreases in SAT mean scores(Illinois 1125 to 1019).
#
# Illinois has experienced a massive increase in participation between 2017 and 2018, essentially trading the ACT for the SAT, as ACT participation fell from 93% to 43%, while SAT participation went from 9% to 99%.
#
#
#
# I shall focus upon Ilinois whom transitioned between the examinations.

# %%
ply.barplots()

# %% [markdown]
# Pictorially the SAT exams recorded quite low participation rates (<10%), given a conglomerate of states with participation in the 50-75% range, yet a group of states with 100% participation. ACT representing contrasting data, has almost no states with lower than 10% participation, yet there is an conglomerate of states with at or near 100% participation. They actually begin to display a slight symmetry between the graphs.

# %%
plt.subplots(figsize = (8,8))
sns.boxplot(data = final[['participation.sat.2017', 'participation.sat.2018', 'participation.act.2017', 'participation.act.2018']], width = 0.5);
plt.title('SAT & ACT Participation', fontsize = 24)
plt.ylabel('Score', fontsize = 22)
plt.ylim(0, 110)
plt.xticks(rotation = 45);

# %%
plt.subplots(figsize = (8,8))
sns.boxplot(data = final[['participation.sat.2017', 'participation.sat.2018', 'participation.act.2017', 'participation.act.2018']], width = 0.5);
plt.title('SAT & ACT Participation', fontsize = 24)
plt.ylabel('Score', fontsize = 22)
plt.ylim(0, 110)
plt.xticks(rotation = 45);

# %%
plt.subplots(figsize = (8,8))
sns.boxplot(data = final[['participation.sat.2017', 'participation.sat.2018', 'participation.act.2017', 'participation.act.2018']], width = 0.5);
plt.title('SAT & ACT Participation', fontsize = 24)
plt.ylabel('Score', fontsize = 22)
plt.ylim(0, 110)
plt.xticks(rotation = 45);

# %% [markdown]
# Within the SAT scatter-plot, one could observe the conglomerate of ACT dominated states within the top left section where SAT participation is quite low, & mean scores being less than a mere 1200. The downward slope of both graphs coveys an indication of a negative association between the variables. This data represents a plasuible conjecture of a selection bias, one could theorise a possible policitial involvement base upon futher research.

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Within the all of the visualisations, one could observe the conglomerate of ACT dominated states where SAT participation is quite low. The downward slope of each graph coveys an indication of a negative association between the variables; this data represents a plasuible conjecture of a selection bias, one could theorise a possible policitial involvement base upon futher research. Within my research one discovers a myriad of controversial topical debates upon whether political biases play an influence over which examination to conduct in their state, yet one would conjecture the contracts are acquired within each state based upon how loyal one is with a political party or another, pure speculation mind you.
#
# https://www.washingtonpost.com/education/2019/03/19/is-it-finally-time-get-rid-sat-act-college-admissions-tests/

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# From this data one shall advise a submission to the Department of Education recommending the ACT exam being terminated from usage, and hence establish a regulation all high schools offer a formatted infusement of the ACT into the SAT funded by the US Govt, through plausible stimulus package increase for states whom follow this regulation.
#
# Additionally innovate and submit formatting to have any specified academic proficiency given an equivalent amount of college preparatory programs avaliable.
#
# Which would produce a greater portion of students seeking to take a singular test and forgo offering the ACT.
#
# Move beyond any political bias associated with any specific examination in order to establish any regulation.

# %% [markdown]
# ## Bonus: Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:
